# %%
import pandas as pd
import numpy as np
from numpy import random

# %% [markdown]
# # Creando un DataFrame

# %%
df = pd.read_csv('../../../Downloads/mastermind-220421-143506.csv', index_col = [0])

# %%
df
# Out:
#            nombre         especialidad  edad  visitas sexo
# 0       SFDX Show             Hardware    30   130855    H
# 1     Sara Nogark     Edición de vídeo    29   114175    M
# 2    Nate Gentile         Programación    31   142545    H
# 3       Bettatech         Programación    31   149462    H
# 4  Antonio Sarosi  Sistemas Operativos    28   132008    H
# 5      Edgar Pons             Robótica    29   143620    H
# 6         s4vitar              Hacking    28   132567    H

# %% [markdown]
# ## Desde un diccionario

# %%
dates = {"nombre": ["SFDX Show", "Sara Nogark","Nate Gentille", "Bettatech", "Antonio Sarosi", "Edgar Pons", "S4vitar"],
        "especialidad": list(df["especialidad"]),
        "Edad": [random.randint(28,32) for _ in range (len(df["nombre"]))],
        "Visitas": [random.randint(1000,2000) for _ in range (len(df["nombre"]))]}

# %%
df_inventado = pd.DataFrame(dates)

# %%
df_inventado
# Out:
#            nombre         especialidad  Edad  Visitas
# 0       SFDX Show             Hardware    30     1732
# 1     Sara Nogark     Edición de vídeo    28     1205
# 2   Nate Gentille         Programación    28     1519
# 3       Bettatech         Programación    31     1767
# 4  Antonio Sarosi  Sistemas Operativos    28     1080
# 5      Edgar Pons             Robótica    31     1010
# 6         S4vitar              Hacking    28     1524

# %%
df_inventado["sexo"] = ["H", "M", "H", "H", "H", "H", "H"]

# %%
df_inventado
# Out:
#            nombre         especialidad  Edad  Visitas sexo
# 0       SFDX Show             Hardware    30     1732    H
# 1     Sara Nogark     Edición de vídeo    28     1205    M
# 2   Nate Gentille         Programación    28     1519    H
# 3       Bettatech         Programación    31     1767    H
# 4  Antonio Sarosi  Sistemas Operativos    28     1080    H
# 5      Edgar Pons             Robótica    31     1010    H
# 6         S4vitar              Hacking    28     1524    H

# %% [markdown]
# # Explorando un DataFrame

# %%
df
# Out:
#            nombre         especialidad  edad  visitas sexo
# 0       SFDX Show             Hardware    30   130855    H
# 1     Sara Nogark     Edición de vídeo    29   114175    M
# 2    Nate Gentile         Programación    31   142545    H
# 3       Bettatech         Programación    31   149462    H
# 4  Antonio Sarosi  Sistemas Operativos    28   132008    H
# 5      Edgar Pons             Robótica    29   143620    H
# 6         s4vitar              Hacking    28   132567    H

# %% [markdown]
# ## sf.head()

# %%
df.head() #Si se coloca en negativo, simplemente resta ese numero de filas del final
# Out:
#            nombre         especialidad  edad  visitas sexo
# 0       SFDX Show             Hardware    30   130855    H
# 1     Sara Nogark     Edición de vídeo    29   114175    M
# 2    Nate Gentile         Programación    31   142545    H
# 3       Bettatech         Programación    31   149462    H
# 4  Antonio Sarosi  Sistemas Operativos    28   132008    H

# %% [markdown]
# ## df.tail()

# %%
df.tail()
# Out:
#            nombre         especialidad  edad  visitas sexo
# 2    Nate Gentile         Programación    31   142545    H
# 3       Bettatech         Programación    31   149462    H
# 4  Antonio Sarosi  Sistemas Operativos    28   132008    H
# 5      Edgar Pons             Robótica    29   143620    H
# 6         s4vitar              Hacking    28   132567    H

# %% [markdown]
# ## df.sample()

# %%
df.sample()
# Out:
#     nombre especialidad  edad  visitas sexo
# 6  s4vitar      Hacking    28   132567    H

# %% [markdown]
# ## df.info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7 entries, 0 to 6
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   nombre        7 non-null      object
#  1   especialidad  7 non-null      object
#  2   edad          7 non-null      int64
#  3   visitas       7 non-null      int64
#  4   sexo          7 non-null      object
# dtypes: int64(2), object(3)
# memory usage: 336.0+ bytes

# %% [markdown]
# ## df.describe()

# %%
df.describe()
# Out:
#             edad        visitas
# count   7.000000       7.000000
# mean   29.428571  135033.142857
# std     1.272418   11590.990631
# min    28.000000  114175.000000
# 25%    28.500000  131431.500000
# 50%    29.000000  132567.000000
# 75%    30.500000  143082.500000
# max    31.000000  149462.000000

# %% [markdown]
# ## df.shape

# %%
df.shape #Filas x Columnas
# Out:
# (7, 5)

# %% [markdown]
# ## df.columns

# %%
df.columns
# Out:
# Index(['nombre', 'especialidad', 'edad', 'visitas', 'sexo'], dtype='object')

# %%
df.columns = ['nombre', 'especialidad', 'anos', 'visitas', 'sexo']

# %%
df.sample()
# Out:
#          nombre  especialidad  anos  visitas sexo
# 2  Nate Gentile  Programación    31   142545    H

# %%
df.columns = ['nombre', 'especialidad', 'edad', 'visitas', 'sexo']

# %%
df.columns
# Out:
# Index(['nombre', 'especialidad', 'edad', 'visitas', 'sexo'], dtype='object')

# %% [markdown]
# ## df.index

# %%
df.index
# Out:
# Int64Index([0, 1, 2, 3, 4, 5, 6], dtype='int64')

# %% [markdown]
# # Seleccion de elementos (Subset)

# %% [markdown]
# ## Acceso mediante etiquetas

# %%
df.head()
# Out:
#            nombre         especialidad  edad  visitas sexo
# 0       SFDX Show             Hardware    30   130855    H
# 1     Sara Nogark     Edición de vídeo    29   114175    M
# 2    Nate Gentile         Programación    31   142545    H
# 3       Bettatech         Programación    31   149462    H
# 4  Antonio Sarosi  Sistemas Operativos    28   132008    H

# %%
df["especialidad"][2]
# Out:
# 'Programación'

# %%
df[df["nombre"] == "Nate Gentile"]["nombre"]
#Aca llamamos una condicion dentro del DataFrame, lo ultimo es lo que quiero que me mueste
# Out:
# 2    Nate Gentile
# Name: nombre, dtype: object

# %% [markdown]
# ## df.iloc[ ]

# %%
df.head()
# Out:
#            nombre         especialidad  edad  visitas sexo
# 0       SFDX Show             Hardware    30   130855    H
# 1     Sara Nogark     Edición de vídeo    29   114175    M
# 2    Nate Gentile         Programación    31   142545    H
# 3       Bettatech         Programación    31   149462    H
# 4  Antonio Sarosi  Sistemas Operativos    28   132008    H

# %%
df.iloc[6,0:2]  #df.iloc[indice, columna] # No es inclusivo el ultimo valor, es decir hay que poner un numero mayor al que bus
# Out:
# nombre          s4vitar
# especialidad    Hacking
# Name: 6, dtype: object

# %% [markdown]
# ## df.loc

# %%
df.head(7)
# Out:
#            nombre         especialidad  edad  visitas sexo
# 0       SFDX Show             Hardware    30   130855    H
# 1     Sara Nogark     Edición de vídeo    29   114175    M
# 2    Nate Gentile         Programación    31   142545    H
# 3       Bettatech         Programación    31   149462    H
# 4  Antonio Sarosi  Sistemas Operativos    28   132008    H
# 5      Edgar Pons             Robótica    29   143620    H
# 6         s4vitar              Hacking    28   132567    H

# %%
df.loc[2, "nombre": "especialidad"]  #df.loc[indice_fila, nombre_columna] #Si es inclusivo
# Out:
# nombre          Nate Gentile
# especialidad    Programación
# Name: 2, dtype: object

# %%
df.loc[2, "nombre": "especialidad"] == df.iloc[2,0:2]
# Out:
# nombre          True
# especialidad    True
# Name: 2, dtype: bool

# %% [markdown]
# # Manipulacion de datos

# %% [markdown]
# ## Cambiar indice

# %% [markdown]
# ### df.set_index()

# %%
df
# Out:
#            nombre         especialidad  edad  visitas sexo
# 0       SFDX Show             Hardware    30   130855    H
# 1     Sara Nogark     Edición de vídeo    29   114175    M
# 2    Nate Gentile         Programación    31   142545    H
# 3       Bettatech         Programación    31   149462    H
# 4  Antonio Sarosi  Sistemas Operativos    28   132008    H
# 5      Edgar Pons             Robótica    29   143620    H
# 6         s4vitar              Hacking    28   132567    H

# %%
df.set_index("nombre", inplace=True)

# %%
df
# Out:
#                        especialidad  edad  visitas sexo
# nombre
# SFDX Show                  Hardware    30   130855    H
# Sara Nogark        Edición de vídeo    29   114175    M
# Nate Gentile           Programación    31   142545    H
# Bettatech              Programación    31   149462    H
# Antonio Sarosi  Sistemas Operativos    28   132008    H
# Edgar Pons                 Robótica    29   143620    H
# s4vitar                     Hacking    28   132567    H

# %%
df.reset_index(inplace = True)

# %%
df
# Out:
#            nombre         especialidad  edad  visitas sexo
# 0       SFDX Show             Hardware    30   130855    H
# 1     Sara Nogark     Edición de vídeo    29   114175    M
# 2    Nate Gentile         Programación    31   142545    H
# 3       Bettatech         Programación    31   149462    H
# 4  Antonio Sarosi  Sistemas Operativos    28   132008    H
# 5      Edgar Pons             Robótica    29   143620    H
# 6         s4vitar              Hacking    28   132567    H

# %%
df_nuevo = df.set_index("nombre")

# %%
df_nuevo.head()
# Out:
#                        especialidad  edad  visitas sexo
# nombre
# SFDX Show                  Hardware    30   130855    H
# Sara Nogark        Edición de vídeo    29   114175    M
# Nate Gentile           Programación    31   142545    H
# Bettatech              Programación    31   149462    H
# Antonio Sarosi  Sistemas Operativos    28   132008    H

# %%
df_nuevo.loc[["Nate Gentile", "s4vitar"], ["edad", "visitas"]]
# Out:
#               edad  visitas
# nombre
# Nate Gentile    31   142545
# s4vitar         28   132567

# %% [markdown]
# ## df.apply() #Aplicar funciones

# %%
df.select_dtypes(include='int64').apply(np.sqrt) #Select dtype es para seleccionar un tipo de datos en todo el dataframe
# Out:
#        edad     visitas
# 0  5.477226  361.738856
# 1  5.385165  337.897914
# 2  5.567764  377.551321
# 3  5.567764  386.603156
# 4  5.291503  363.329052
# 5  5.385165  378.972295
# 6  5.291503  364.097514

# %%
df["especialidad_mayus"] = df["especialidad"].apply(lambda x: x.upper())

# %%
df
# Out:
#            nombre         especialidad  edad  visitas sexo  \
# 0       SFDX Show             HARDWARE    30   130855    H
# 1     Sara Nogark     EDICIÓN DE VÍDEO    29   114175    M
# 2    Nate Gentile         PROGRAMACIÓN    31   142545    H
# 3       Bettatech         PROGRAMACIÓN    31   149462    H
# 4  Antonio Sarosi  SISTEMAS OPERATIVOS    28   132008    H
# 5      Edgar Pons             ROBÓTICA    29   143620    H
# 6         s4vitar              HACKING    28   132567    H
#
#     especialidad_mayus
# 0             HARDWARE
# 1     EDICIÓN DE VÍDEO
# 2         PROGRAMACIÓN
# 3         PROGRAMACIÓN
# 4  SISTEMAS OPERATIVOS
# 5             ROBÓTICA
# 6              HACKING

# %% [markdown]
# ## df.drop()

# %%
df.drop("especialidad_mayus", inplace=True, axis=1)

# %%
df
# Out:
#            nombre         especialidad  edad  visitas sexo
# 0       SFDX Show             HARDWARE    30   130855    H
# 1     Sara Nogark     EDICIÓN DE VÍDEO    29   114175    M
# 2    Nate Gentile         PROGRAMACIÓN    31   142545    H
# 3       Bettatech         PROGRAMACIÓN    31   149462    H
# 4  Antonio Sarosi  SISTEMAS OPERATIVOS    28   132008    H
# 5      Edgar Pons             ROBÓTICA    29   143620    H
# 6         s4vitar              HACKING    28   132567    H

# %%
df
# Out:
#            nombre         especialidad  edad  visitas sexo
# 0       SFDX Show             HARDWARE    30   130855    H
# 1     Sara Nogark     EDICIÓN DE VÍDEO    29   114175    M
# 2    Nate Gentile         PROGRAMACIÓN    31   142545    H
# 3       Bettatech         PROGRAMACIÓN    31   149462    H
# 4  Antonio Sarosi  SISTEMAS OPERATIVOS    28   132008    H
# 5      Edgar Pons             ROBÓTICA    29   143620    H
# 6         s4vitar              HACKING    28   132567    H

# %% [markdown]
# ## df.drop_duplicates()

# %%
new_df = df.copy()

# %%
new_df
# Out:
#            nombre         especialidad  edad  visitas sexo
# 0       SFDX Show             HARDWARE    30   130855    H
# 1     Sara Nogark     EDICIÓN DE VÍDEO    29   114175    M
# 2    Nate Gentile         PROGRAMACIÓN    31   142545    H
# 3       Bettatech         PROGRAMACIÓN    31   149462    H
# 4  Antonio Sarosi  SISTEMAS OPERATIVOS    28   132008    H
# 5      Edgar Pons             ROBÓTICA    29   143620    H
# 6         s4vitar              HACKING    28   132567    H

# %%
new_df.drop_duplicates("edad", keep="last")
# Out:
#        nombre  especialidad  edad  visitas sexo
# 0   SFDX Show      HARDWARE    30   130855    H
# 3   Bettatech  PROGRAMACIÓN    31   149462    H
# 5  Edgar Pons      ROBÓTICA    29   143620    H
# 6     s4vitar       HACKING    28   132567    H

# %% [markdown]
# ## df.nlargest()

# %%
df.nlargest(len(df),"visitas")
# Out:
#            nombre         especialidad  edad  visitas sexo
# 3       Bettatech         PROGRAMACIÓN    31   149462    H
# 5      Edgar Pons             ROBÓTICA    29   143620    H
# 2    Nate Gentile         PROGRAMACIÓN    31   142545    H
# 6         s4vitar              HACKING    28   132567    H
# 4  Antonio Sarosi  SISTEMAS OPERATIVOS    28   132008    H
# 0       SFDX Show             HARDWARE    30   130855    H
# 1     Sara Nogark     EDICIÓN DE VÍDEO    29   114175    M

# %% [markdown]
# ## df.nsmallest()

# %%
df.nsmallest(3,"visitas")
# Out:
#            nombre         especialidad  edad  visitas sexo
# 1     Sara Nogark     EDICIÓN DE VÍDEO    29   114175    M
# 0       SFDX Show             HARDWARE    30   130855    H
# 4  Antonio Sarosi  SISTEMAS OPERATIVOS    28   132008    H

# %% [markdown]
# ## df.sort_values()

# %%
df.sort_values(by="visitas", ascending=False)
# Out:
#            nombre         especialidad  edad  visitas sexo
# 3       Bettatech         PROGRAMACIÓN    31   149462    H
# 5      Edgar Pons             ROBÓTICA    29   143620    H
# 2    Nate Gentile         PROGRAMACIÓN    31   142545    H
# 6         s4vitar              HACKING    28   132567    H
# 4  Antonio Sarosi  SISTEMAS OPERATIVOS    28   132008    H
# 0       SFDX Show             HARDWARE    30   130855    H
# 1     Sara Nogark     EDICIÓN DE VÍDEO    29   114175    M

# %%
df.sort_values(by=["edad", "visitas"], ascending=False)
# Out:
#            nombre         especialidad  edad  visitas sexo
# 3       Bettatech         PROGRAMACIÓN    31   149462    H
# 2    Nate Gentile         PROGRAMACIÓN    31   142545    H
# 0       SFDX Show             HARDWARE    30   130855    H
# 5      Edgar Pons             ROBÓTICA    29   143620    H
# 1     Sara Nogark     EDICIÓN DE VÍDEO    29   114175    M
# 6         s4vitar              HACKING    28   132567    H
# 4  Antonio Sarosi  SISTEMAS OPERATIVOS    28   132008    H

# %% [markdown]
# ## df.value_counts()

# %%
df.value_counts("edad")
# Out:
# edad
# 28    2
# 29    2
# 31    2
# 30    1
# dtype: int64

# %% [markdown]
# ## df.rename()

# %%
df.rename(columns={"edad": "viejo"})
# Out:
#            nombre         especialidad  viejo  visitas sexo
# 0       SFDX Show             HARDWARE     30   130855    H
# 1     Sara Nogark     EDICIÓN DE VÍDEO     29   114175    M
# 2    Nate Gentile         PROGRAMACIÓN     31   142545    H
# 3       Bettatech         PROGRAMACIÓN     31   149462    H
# 4  Antonio Sarosi  SISTEMAS OPERATIVOS     28   132008    H
# 5      Edgar Pons             ROBÓTICA     29   143620    H
# 6         s4vitar              HACKING     28   132567    H

# %%
df
# Out:
#            nombre         especialidad  edad  visitas sexo
# 0       SFDX Show             HARDWARE    30   130855    H
# 1     Sara Nogark     EDICIÓN DE VÍDEO    29   114175    M
# 2    Nate Gentile         PROGRAMACIÓN    31   142545    H
# 3       Bettatech         PROGRAMACIÓN    31   149462    H
# 4  Antonio Sarosi  SISTEMAS OPERATIVOS    28   132008    H
# 5      Edgar Pons             ROBÓTICA    29   143620    H
# 6         s4vitar              HACKING    28   132567    H

# %% [markdown]
# # Funciones Avanzadas

# %% [markdown]
# ## pd.concat

# %%
nuevo_df = df.copy()

# %%
nuevo_df["nombre"] = ["Batman", "Spiderman", "Loki", "Thor", "Iron Man", "Capitan America", "Flash"]

# %%
nuevo_df
# Out:
#             nombre         especialidad  edad  visitas sexo
# 0           Batman             Hardware    30   130855    H
# 1        Spiderman     Edición de vídeo    29   114175    M
# 2             Loki         Programación    31   142545    H
# 3             Thor         Programación    31   149462    H
# 4         Iron Man  Sistemas Operativos    28   132008    H
# 5  Capitan America             Robótica    29   143620    H
# 6            Flash              Hacking    28   132567    H

# %%
df = pd.concat([df, nuevo_df]).reset_index(drop=True) #tambien se puede con ".reset_index(drop=True)"

# %%
df
# Out:
#              nombre         especialidad  edad  visitas sexo
# 0         SFDX Show             Hardware    30   130855    H
# 1       Sara Nogark     Edición de vídeo    29   114175    M
# 2      Nate Gentile         Programación    31   142545    H
# 3         Bettatech         Programación    31   149462    H
# 4    Antonio Sarosi  Sistemas Operativos    28   132008    H
# 5        Edgar Pons             Robótica    29   143620    H
# 6           s4vitar              Hacking    28   132567    H
# 7            Batman             Hardware    30   130855    H
# 8         Spiderman     Edición de vídeo    29   114175    M
# 9              Loki         Programación    31   142545    H
# 10             Thor         Programación    31   149462    H
# 11         Iron Man  Sistemas Operativos    28   132008    H
# 12  Capitan America             Robótica    29   143620    H
# 13            Flash              Hacking    28   132567    H

# %% [markdown]
# ## df.where()

# %%
filtro1 = df["especialidad"] == "Programación"
filtro2 = df["visitas"] > 12000

# %%
df.where(filtro1 & filtro2).dropna().loc[:, "nombre"]
# Out:
# 2     Nate Gentile
# 3        Bettatech
# 9             Loki
# 10            Thor
# Name: nombre, dtype: object

# %% [markdown]
# ## df.groupby()

# %%
df.groupby("especialidad").sum()["visitas"]
# Out:
# C:\Users\Michael\AppData\Local\Temp\ipykernel_17956\3740171205.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("especialidad").sum()["visitas"]
# especialidad
# Edición de vídeo       228350
# Hacking                265134
# Hardware               261710
# Programación           584014
# Robótica               287240
# Sistemas Operativos    264016
# Name: visitas, dtype: int64

# %%
df.groupby("sexo").max()
# Out:
#          nombre         especialidad  edad  visitas
# sexo
# H       s4vitar  Sistemas Operativos    31   149462
# M     Spiderman     Edición de vídeo    29   114175

# %%
df.groupby(["sexo", "especialidad"]).max()
# Out:
#                               nombre  edad  visitas
# sexo especialidad
# H    Hacking                 s4vitar    28   132567
#      Hardware              SFDX Show    30   130855
#      Programación               Thor    31   149462
#      Robótica             Edgar Pons    29   143620
#      Sistemas Operativos    Iron Man    28   132008
# M    Edición de vídeo      Spiderman    29   114175

# %% [markdown]
# ## pd.pivot_table()

# %%
pd.pivot_table(df, index="sexo", columns=["edad"], aggfunc=np.sum)
# Out:
# C:\Users\Michael\AppData\Local\Temp\ipykernel_17956\1061789207.py:1: FutureWarning: The operation <function sum at 0x000001B70A2B5F30> failed on a column. If any error is raised, this will raise an exception in a future version of pandas. Drop these columns to avoid this warning.
#   pd.pivot_table(df, index="sexo", columns=["edad"], aggfunc=np.sum)
#        visitas
# edad        28        29        30        31
# sexo
# H     529150.0  287240.0  261710.0  584014.0
# M          NaN  228350.0       NaN       NaN

# %%
pd.pivot_table(df, index=["sexo"], values=["nombre"], columns= ["especialidad"], aggfunc=np.max)
# Out:
#                        nombre                                               \
# especialidad Edición de vídeo  Hacking   Hardware Programación    Robótica
# sexo
# H                         NaN  s4vitar  SFDX Show         Thor  Edgar Pons
# M                   Spiderman      NaN        NaN          NaN         NaN
#
#
# especialidad Sistemas Operativos
# sexo
# H                       Iron Man
# M                            NaN

# %% [markdown]
# # Fechas

# %% [markdown]
# ## Creando fechas

# %% [markdown]
# ### pd.date_range()

# %%
len(df)
# Out:
# 14

# %%
fecha = pd.date_range(start="1 January 2022", end="1 February 2023", freq="MS")

# %%
fecha
# Out:
# DatetimeIndex(['2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01',
#                '2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01',
#                '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01',
#                '2023-01-01', '2023-02-01'],
#               dtype='datetime64[ns]', freq='MS')

# %%
len(fecha)
# Out:
# 14

# %%
df["fecha"] =['2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01',
               '2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01',
               '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01',
               '2023-01-01', '2023-02-01']

# %%
df
# Out:
#              nombre         especialidad  edad  visitas sexo       fecha
# 0         SFDX Show             Hardware    30   130855    H  2022-01-01
# 1       Sara Nogark     Edición de vídeo    29   114175    M  2022-02-01
# 2      Nate Gentile         Programación    31   142545    H  2022-03-01
# 3         Bettatech         Programación    31   149462    H  2022-04-01
# 4    Antonio Sarosi  Sistemas Operativos    28   132008    H  2022-05-01
# 5        Edgar Pons             Robótica    29   143620    H  2022-06-01
# 6           s4vitar              Hacking    28   132567    H  2022-07-01
# 7            Batman             Hardware    30   130855    H  2022-08-01
# 8         Spiderman     Edición de vídeo    29   114175    M  2022-09-01
# 9              Loki         Programación    31   142545    H  2022-10-01
# 10             Thor         Programación    31   149462    H  2022-11-01
# 11         Iron Man  Sistemas Operativos    28   132008    H  2022-12-01
# ...

# %%
df
# Out:
#              nombre         especialidad  edad  visitas sexo
# 0         SFDX Show             Hardware    30   130855    H
# 1       Sara Nogark     Edición de vídeo    29   114175    M
# 2      Nate Gentile         Programación    31   142545    H
# 3         Bettatech         Programación    31   149462    H
# 4    Antonio Sarosi  Sistemas Operativos    28   132008    H
# 5        Edgar Pons             Robótica    29   143620    H
# 6           s4vitar              Hacking    28   132567    H
# 7            Batman             Hardware    30   130855    H
# 8         Spiderman     Edición de vídeo    29   114175    M
# 9              Loki         Programación    31   142545    H
# 10             Thor         Programación    31   149462    H
# 11         Iron Man  Sistemas Operativos    28   132008    H
# 12  Capitan America             Robótica    29   143620    H
# 13            Flash              Hacking    28   132567    H

# %%
df.set_index(pd.DatetimeIndex(fecha), inplace=True)

# %%
df
# Out:
#                      nombre         especialidad  edad  visitas sexo
# 2022-01-01        SFDX Show             Hardware    30   130855    H
# 2022-02-01      Sara Nogark     Edición de vídeo    29   114175    M
# 2022-03-01     Nate Gentile         Programación    31   142545    H
# 2022-04-01        Bettatech         Programación    31   149462    H
# 2022-05-01   Antonio Sarosi  Sistemas Operativos    28   132008    H
# 2022-06-01       Edgar Pons             Robótica    29   143620    H
# 2022-07-01          s4vitar              Hacking    28   132567    H
# 2022-08-01           Batman             Hardware    30   130855    H
# 2022-09-01        Spiderman     Edición de vídeo    29   114175    M
# 2022-10-01             Loki         Programación    31   142545    H
# 2022-11-01             Thor         Programación    31   149462    H
# 2022-12-01         Iron Man  Sistemas Operativos    28   132008    H
# 2023-01-01  Capitan America             Robótica    29   143620    H
# ...

# %%
formato = "%d/%m/%Y"

# %%
df.index.strftime(formato)
# Out:
# Index(['01/01/2022', '01/02/2022', '01/03/2022', '01/04/2022', '01/05/2022',
#        '01/06/2022', '01/07/2022', '01/08/2022', '01/09/2022', '01/10/2022',
#        '01/11/2022', '01/12/2022', '01/01/2023', '01/02/2023'],
#       dtype='object')

# %%
df.index = df.index.strftime(formato)

# %%
df
# Out:
#                      nombre         especialidad  edad  visitas sexo
# 01/01/2022        SFDX Show             Hardware    30   130855    H
# 01/02/2022      Sara Nogark     Edición de vídeo    29   114175    M
# 01/03/2022     Nate Gentile         Programación    31   142545    H
# 01/04/2022        Bettatech         Programación    31   149462    H
# 01/05/2022   Antonio Sarosi  Sistemas Operativos    28   132008    H
# 01/06/2022       Edgar Pons             Robótica    29   143620    H
# 01/07/2022          s4vitar              Hacking    28   132567    H
# 01/08/2022           Batman             Hardware    30   130855    H
# 01/09/2022        Spiderman     Edición de vídeo    29   114175    M
# 01/10/2022             Loki         Programación    31   142545    H
# 01/11/2022             Thor         Programación    31   149462    H
# 01/12/2022         Iron Man  Sistemas Operativos    28   132008    H
# 01/01/2023  Capitan America             Robótica    29   143620    H
# ...
